# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('CampaignPerformance.csv')
df
# Out:
#             dates                        campaign_name  \
# 0      2024-04-29           usp_search_aptntska_250124
# 1      2024-05-02  usp_2_lead-gen-2_top4-states_050424
# 2      2024-05-02  usp_2_lead-gen-2_top4-states_050424
# 3      2024-05-02  usp_2_lead-gen-2_top4-states_050424
# 4      2024-05-02  usp_2_lead-gen-2_top4-states_050424
# ...           ...                                  ...
# 28492  2024-03-12        usp_ms + coop campaign_240224
# 28493  2024-03-12        usp_ms + coop campaign_240224
# 28494  2024-03-12      usp study abroad_generic_240224
# 28495  2024-03-12      usp study abroad_generic_240224
# 28496  2024-03-12      usp study abroad_generic_240224
#
#                            creative_name  total_spent  impressions  clicks  \
# 0                                     --      6766.15         1250     220
# 1       #7 ( graphic ) - get a free pass       946.38         3154       9
# 2               usp_s3_never-been-easier       170.40         2695       8
# 3                     usp_s4_do-you-have        55.65          577       2
# 4                    usp_s1_we-guarantee       296.94         1466      10
# ...                                  ...          ...          ...     ...
# 28492                    usp_rg_videoad5        67.18          268       1
# 28493                    usp_rg_videoad5        50.65           75       1
# 28494  usp_webinar_saturdayfuture - copy        11.34           28       0
# 28495  usp_webinar_saturdayfuture - copy       136.97          134       0
# 28496         usp_webinar_saturdayfuture       242.59           24       0
#
#        click_through_rate  leads  platform  \
# 0                0.176000   25.0    google
# 1                0.285352    1.0  facebook
# 2                0.296846    0.0  facebook
# 3                0.346620    0.0  facebook
# 4                0.682128    1.0  facebook
# ...                   ...    ...       ...
# 28492            0.373134    0.0  facebook
# 28493            1.333333    0.0  facebook
# 28494            0.000000    0.0  facebook
# 28495            0.000000    0.0  facebook
# 28496            0.000000    0.0  facebook
#
#                                   adset_name
# 0                                   gmat/gre
# 1                         usp-2_ka_tn_050424
# 2                         usp-2_ka_tn_050424
# 3                         usp-2_ka_tn_050424
# 4                         usp-2_ap_ts_050424
# ...                                      ...
# 28492        ms + coop ka&tn ad set - 240224
# 28493    ms + coop all india ad set - 240224
# 28494      ap&ts generic leads ad set_240224
# 28495      ka&tn generic leads ad set_240224
# 28496  all india generic leads ad set_240224
#
# [28497 rows x 10 columns]

# %%
df[df['campaign_name']=='usp_2_lead-gen-2_top4-states_050424']
# Out:
#             dates                        campaign_name  \
# 1      2024-05-02  usp_2_lead-gen-2_top4-states_050424
# 2      2024-05-02  usp_2_lead-gen-2_top4-states_050424
# 3      2024-05-02  usp_2_lead-gen-2_top4-states_050424
# 4      2024-05-02  usp_2_lead-gen-2_top4-states_050424
# 5      2024-05-02  usp_2_lead-gen-2_top4-states_050424
# ...           ...                                  ...
# 27730  2024-04-08  usp_2_lead-gen-2_top4-states_050424
# 27731  2024-04-08  usp_2_lead-gen-2_top4-states_050424
# 28149  2024-04-05  usp_2_lead-gen-2_top4-states_050424
# 28269  2024-04-07  usp_2_lead-gen-2_top4-states_050424
# 28284  2024-04-07  usp_2_lead-gen-2_top4-states_050424
#
#                                            creative_name  total_spent  \
# 1                       #7 ( graphic ) - get a free pass       946.38
# 2                               usp_s3_never-been-easier       170.40
# 3                                     usp_s4_do-you-have        55.65
# 4                                    usp_s1_we-guarantee       296.94
# 5                                     usp_s4_do-you-have        64.11
# ...                                                  ...          ...
# 27730                               last chance_static-4         8.67
# 27731  #4 ( graphic ) - how to get admmission in your...        14.08
# 28149  #5 ( graphic ) - get master's degree in just 1...         4.00
# 28269                              10-days left_static-2         2.17
# 28284                               last chance_static-4        21.14
#
#        impressions  clicks  click_through_rate  leads  platform  \
# 1             3154       9            0.285352    1.0  facebook
# 2             2695       8            0.296846    0.0  facebook
# 3              577       2            0.346620    0.0  facebook
# 4             1466      10            0.682128    1.0  facebook
# 5             1115       3            0.269058    0.0  facebook
# ...            ...     ...                 ...    ...       ...
# 27730           23       0            0.000000    0.0  facebook
# 27731            6       0            0.000000    0.0  facebook
# 28149           11       0            0.000000    0.0  facebook
# 28269           17       0            0.000000    0.0  facebook
# 28284           54       1            1.851852    0.0  facebook
#
#                adset_name
# 1      usp-2_ka_tn_050424
# 2      usp-2_ka_tn_050424
# 3      usp-2_ka_tn_050424
# 4      usp-2_ap_ts_050424
# 5      usp-2_ap_ts_050424
# ...                   ...
# 27730  usp-2_ka_tn_050424
# 27731  usp-2_ap_ts_050424
# 28149  usp-2_ka_tn_050424
# 28269  usp-2_ka_tn_050424
# 28284  usp-2_ap_ts_050424
#
# [741 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28497 entries, 0 to 28496
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   dates               28497 non-null  object
#  1   campaign_name       28497 non-null  object
#  2   creative_name       28497 non-null  object
#  3   total_spent         28497 non-null  float64
#  4   impressions         28497 non-null  int64
#  5   clicks              28497 non-null  int64
#  6   click_through_rate  28497 non-null  float64
#  7   leads               28497 non-null  float64
#  8   platform            28497 non-null  object
#  9   adset_name          24250 non-null  object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 2.2+ MB

# %%
df_group=df[['platform','total_spent','impressions','clicks','leads']].groupby('platform').sum()
plt.figure(figsize=(10, 6))
plt.pie(df_group['total_spent'], labels=df_group.index, autopct='%1.1f%%')
plt.title('Total Spend by Platform')
# Out:
# Text(0.5, 1.0, 'Total Spend by Platform')

# %%
df_group
# Out:
#           total_spent  impressions  clicks     leads
# platform
# facebook   8970978.10     43202018  270165  27536.00
# google     1648768.35      8094970  165603   3630.34
# linkedin   5205343.00     16642988   99833   2868.00

# %%
plt.figure(figsize=(10, 6))
plt.pie(df_group['leads'], labels=df_group.index, autopct='%1.1f%%')
plt.title('Total leads by Platform')
# Out:
# Text(0.5, 1.0, 'Total leads by Platform')

# %%
df_cp = df.groupby('campaign_name').agg({
    'platform': 'first',
    'total_spent': 'sum',
    'impressions': 'sum',
    'clicks': 'sum',
    'leads': 'sum'
}).reset_index()
df_cp.sort_values(by='leads',inplace=True)
df_cp.reset_index(drop=True, inplace=True)
df_cp.head(10)
# Out:
#                                        campaign_name  platform  total_spent  \
# 0  usp masterclass cold [ 14th dec ] - link click ad  facebook     10452.55
# 1                     us_pathway_2_lead_gen_4_220324  linkedin    103022.64
# 2       usp_video_all-india_lead-gen_keywords_110324    google     25865.85
# 3        usp_video_india_ex-aptltska_lead-gen_160224    google     76059.42
# 4  xcbo - usp masterclass cold [ 7th dec ] - high...  facebook     13562.84
# 5  usp masterclass cold [ 31st oct ] - more volum...  facebook     92486.22
# 6                 usp_video_aptltska_lead-gen_160224    google     89981.07
# 7  usp_program_more-volume_with-logic_south-state...  facebook    109130.82
# 8              usp_program_lead-gen_4_mar&mba_140223  facebook     74697.63
# 9  xcbo - usp masterclass cold [ 23rd nov ] - mor...  facebook     44937.43
#
#    impressions  clicks   leads
# 0       871201   18578    0.00
# 1       348534    2082   39.00
# 2       442455   10896   52.00
# 3      2302262   31294   82.00
# 4        62852     644  111.00
# 5       326809    2939  134.00
# 6      1546844   29492  155.98
# 7       556972    2981  171.00
# 8       261944    1455  173.00
# 9       195004    1594  208.00

# %%
plt.figure(figsize=(14, 12))
sns.barplot(data=df_cp, x='leads', y='campaign_name', hue='platform')
plt.title('Top Campaigns by Leads ')
plt.xlabel('Leads')
plt.ylabel('Campaign Name')
plt.legend(title='Platform')
plt.show()

# %%
df_int = df_cp[['impressions', 'clicks', 'campaign_name', 'platform']].copy()
df_int.loc[:, 'interested'] = df_int['impressions'] / df_int['clicks']
df_int.sort_values(by='interested',ascending=False,inplace=True)
plt.figure(figsize=(14, 12))
sns.barplot(data=df_int, y='campaign_name', x='interested', hue='platform', palette='Set2')
plt.title('Campaigns by Interested Ratio ')
plt.xlabel('Interested Ratio')
plt.ylabel('Campaign Name')
plt.legend(title='Platform')
plt.show()
